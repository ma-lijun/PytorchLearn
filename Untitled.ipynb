# %% [markdown]
# 1.3 Pytorch Neural Networks(神经网络)

# %% [markdown]
# ### 1. torch.flatten()

# %% [markdown]
# > torch.flatten() 函数应用

# %%
import torch

# %%
a = torch.rand(2,3)

# %%
a
# Out:
# tensor([[0.0941, 0.4099, 0.9020],
#         [0.5728, 0.8977, 0.3685]])

# %%
torch.flatten(a, 1)
# Out:
# tensor([[0.0941, 0.4099, 0.9020],
#         [0.5728, 0.8977, 0.3685]])

# %%
torch.flatten(a)
# Out:
# tensor([0.0941, 0.4099, 0.9020, 0.5728, 0.8977, 0.3685])

# %%
b = torch.rand(3,6,5,5)

# %%
b
# Out:
# tensor([[[[0.8153, 0.7716, 0.8412, 0.5707, 0.0051],
#           [0.3004, 0.9961, 0.1391, 0.6440, 0.8068],
#           [0.4856, 0.7590, 0.1566, 0.6883, 0.4714],
#           [0.6907, 0.9003, 0.7570, 0.6067, 0.9369],
#           [0.8799, 0.4922, 0.3554, 0.2044, 0.5362]],
#
#          [[0.2984, 0.0461, 0.3748, 0.3181, 0.6643],
#           [0.9942, 0.3578, 0.2648, 0.3287, 0.6167],
#           [0.7680, 0.6563, 0.6186, 0.0420, 0.4582],
#           [0.2641, 0.6733, 0.3413, 0.3632, 0.3422],
#           [0.1477, 0.2970, 0.7633, 0.0175, 0.9872]],
#
#          [[0.6704, 0.5947, 0.2126, 0.0591, 0.9304],
#           [0.3228, 0.1281, 0.5098, 0.1192, 0.6370],
#           [0.8266, 0.2598, 0.9032, 0.7148, 0.8725],
#           [0.6817, 0.4239, 0.6201, 0.2347, 0.8913],
#           [0.5604, 0.8155, 0.2645, 0.1612, 0.2896]],
#
#          [[0.2034, 0.2679, 0.3660, 0.2274, 0.2233],
#           [0.1504, 0.7075, 0.2553, 0.1913, 0.5441],
#           [0.4002, 0.0316, 0.6207, 0.6536, 0.6895],
# ...

# %%
torch.flatten(b, 1)
# Out:
# tensor([[0.8153, 0.7716, 0.8412, 0.5707, 0.0051, 0.3004, 0.9961, 0.1391, 0.6440,
#          0.8068, 0.4856, 0.7590, 0.1566, 0.6883, 0.4714, 0.6907, 0.9003, 0.7570,
#          0.6067, 0.9369, 0.8799, 0.4922, 0.3554, 0.2044, 0.5362, 0.2984, 0.0461,
#          0.3748, 0.3181, 0.6643, 0.9942, 0.3578, 0.2648, 0.3287, 0.6167, 0.7680,
#          0.6563, 0.6186, 0.0420, 0.4582, 0.2641, 0.6733, 0.3413, 0.3632, 0.3422,
#          0.1477, 0.2970, 0.7633, 0.0175, 0.9872, 0.6704, 0.5947, 0.2126, 0.0591,
#          0.9304, 0.3228, 0.1281, 0.5098, 0.1192, 0.6370, 0.8266, 0.2598, 0.9032,
#          0.7148, 0.8725, 0.6817, 0.4239, 0.6201, 0.2347, 0.8913, 0.5604, 0.8155,
#          0.2645, 0.1612, 0.2896, 0.2034, 0.2679, 0.3660, 0.2274, 0.2233, 0.1504,
#          0.7075, 0.2553, 0.1913, 0.5441, 0.4002, 0.0316, 0.6207, 0.6536, 0.6895,
#          0.5822, 0.8647, 0.2696, 0.3787, 0.4918, 0.2016, 0.9540, 0.5374, 0.1557,
#          0.7091, 0.2436, 0.9309, 0.8508, 0.4384, 0.2284, 0.3750, 0.5725, 0.6985,
# ...

# %%
b.shape
# Out:
# torch.Size([3, 6, 5, 5])

# %%
torch.flatten(b, 1).shape
# Out:
# torch.Size([3, 150])

# %%
torch.flatten(b, 2)
# Out:
# tensor([[[0.8153, 0.7716, 0.8412, 0.5707, 0.0051, 0.3004, 0.9961, 0.1391,
#           0.6440, 0.8068, 0.4856, 0.7590, 0.1566, 0.6883, 0.4714, 0.6907,
#           0.9003, 0.7570, 0.6067, 0.9369, 0.8799, 0.4922, 0.3554, 0.2044,
#           0.5362],
#          [0.2984, 0.0461, 0.3748, 0.3181, 0.6643, 0.9942, 0.3578, 0.2648,
#           0.3287, 0.6167, 0.7680, 0.6563, 0.6186, 0.0420, 0.4582, 0.2641,
#           0.6733, 0.3413, 0.3632, 0.3422, 0.1477, 0.2970, 0.7633, 0.0175,
#           0.9872],
#          [0.6704, 0.5947, 0.2126, 0.0591, 0.9304, 0.3228, 0.1281, 0.5098,
#           0.1192, 0.6370, 0.8266, 0.2598, 0.9032, 0.7148, 0.8725, 0.6817,
#           0.4239, 0.6201, 0.2347, 0.8913, 0.5604, 0.8155, 0.2645, 0.1612,
#           0.2896],
#          [0.2034, 0.2679, 0.3660, 0.2274, 0.2233, 0.1504, 0.7075, 0.2553,
#           0.1913, 0.5441, 0.4002, 0.0316, 0.6207, 0.6536, 0.6895, 0.5822,
#           0.8647, 0.2696, 0.3787, 0.4918, 0.2016, 0.9540, 0.5374, 0.1557,
#           0.7091],
# ...

# %%
torch.flatten(b, 2).shape
# Out:
# torch.Size([3, 6, 25])
